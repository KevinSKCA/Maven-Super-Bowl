# %%
import pandas as pd

# %%
import os

# %%
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel("F:\\data analyst google\\Super+Bowl+Commercials\\edit_data.xlsx")
dataset
# Out:
#      Year      Brand                                 Superbowl Ads Link  \
# 0    2000    E-Trade  https://superbowl-ads.com/2000-etrade-monkey-d...
# 1    2000    E-Trade  https://superbowl-ads.com/2000-etrade-money-ou...
# 2    2000  Budweiser  https://superbowl-ads.com/2000-budweiser-whaas...
# 3    2000  Bud Light  https://superbowl-ads.com/2000-bud-light-hold-...
# 4    2000  Budweiser  https://superbowl-ads.com/2000-budweiser-talki...
# ..    ...        ...                                                ...
# 244  2021    E-Trade  https://www.superbowl-ads.com/2021-etrade-work...
# 245  2021     Toyota  https://www.superbowl-ads.com/2021-toyota-jess...
# 246  2021  Bud Light  https://www.superbowl-ads.com/2021-bud-light-l...
# 247  2021    Doritos  https://www.superbowl-ads.com/2021-doritos-3d-...
# 248  2021  Bud Light  https://www.superbowl-ads.com/2021-bud-light-l...
#
#                                          Youtube Link  Funny  \
# ...

# %%
dataset_modified = dataset.copy()
dataset_modified
# Out:
#      Year      Brand                                 Superbowl Ads Link  \
# 0    2000    E-Trade  https://superbowl-ads.com/2000-etrade-monkey-d...
# 1    2000    E-Trade  https://superbowl-ads.com/2000-etrade-money-ou...
# 2    2000  Budweiser  https://superbowl-ads.com/2000-budweiser-whaas...
# 3    2000  Bud Light  https://superbowl-ads.com/2000-bud-light-hold-...
# 4    2000  Budweiser  https://superbowl-ads.com/2000-budweiser-talki...
# ..    ...        ...                                                ...
# 244  2021    E-Trade  https://www.superbowl-ads.com/2021-etrade-work...
# 245  2021     Toyota  https://www.superbowl-ads.com/2021-toyota-jess...
# 246  2021  Bud Light  https://www.superbowl-ads.com/2021-bud-light-l...
# 247  2021    Doritos  https://www.superbowl-ads.com/2021-doritos-3d-...
# 248  2021  Bud Light  https://www.superbowl-ads.com/2021-bud-light-l...
#
#                                          Youtube Link  Funny  \
# ...

# %%
columns_to_drop = ['Superbowl Ads Link', 'Youtube Link',  'Youtube Likes', 'TV Viewers']

# %%
dataset_edited = dataset_modified.drop(columns = columns_to_drop)
dataset_edited
# Out:
#      Year      Brand  Funny  Shows Product Quickly  Patriotic  Celebrity  \
# 0    2000    E-Trade   True                   True      False      False
# 1    2000    E-Trade   True                   True      False      False
# 2    2000  Budweiser   True                   True      False      False
# 3    2000  Bud Light   True                   True      False      False
# 4    2000  Budweiser   True                  False      False      False
# ..    ...        ...    ...                    ...        ...        ...
# 244  2021    E-Trade   True                  False      False       True
# 245  2021     Toyota  False                  False       True      False
# 246  2021  Bud Light   True                   True      False       True
# 247  2021    Doritos   True                  False      False       True
# 248  2021  Bud Light   True                   True      False      False
#
#      Danger  Animals  Uses Sex  Length  Estimated Cost  Youtube Views
# ...

# %%
dataset_edited.Brand.unique()
# Out:
# array(['E-Trade', 'Budweiser', 'Bud Light', 'Pepsi', 'Doritos', 'NFL',
#        'Toyota', 'Coca-Cola', 'Hyundai', 'Kia'], dtype=object)

# %%
car_brand = ['Toyota', 'Hyundai', 'Kia']
dataset_edited_car = dataset_edited[dataset_edited.Brand.isin(car_brand)]
dataset_edited_car
# Out:
#      Year    Brand  Funny  Shows Product Quickly  Patriotic  Celebrity  \
# 47   2004   Toyota   True                   True      False      False
# 80   2007   Toyota  False                   True      False      False
# 84   2008  Hyundai  False                   True      False      False
# 99   2009  Hyundai   True                   True      False      False
# 110  2009  Hyundai  False                   True      False      False
# 111  2010  Hyundai  False                   True       True      False
# 119  2010  Hyundai  False                  False      False       True
# 121  2010      Kia   True                   True      False      False
# 125  2011      Kia   True                   True      False      False
# 129  2011  Hyundai   True                  False      False      False
# 131  2011  Hyundai  False                  False      False      False
# 132  2011  Hyundai  False                  False      False      False
# ...

# %%
dataset_edited_car_two = dataset_edited_car.loc[dataset_edited_car.groupby('Year')['Youtube Views'].idxmax()].reset_index()
dataset_edited_car_two
# Out:
#     index  Year    Brand  Funny  Shows Product Quickly  Patriotic  Celebrity  \
# 0      47  2004   Toyota   True                   True      False      False
# 1      80  2007   Toyota  False                   True      False      False
# 2      84  2008  Hyundai  False                   True      False      False
# 3      99  2009  Hyundai   True                   True      False      False
# 4     119  2010  Hyundai  False                  False      False       True
# 5     125  2011      Kia   True                   True      False      False
# 6     139  2012   Toyota   True                   True      False      False
# 7     153  2013  Hyundai   True                   True      False      False
# 8     174  2014  Hyundai   True                  False      False      False
# 9     182  2015      Kia   True                   True      False       True
# 10    198  2016   Toyota   True                  False      False      False
# ...

# %%
dataset_edited_car_two['Funny'].value_counts(normalize=True)
# Out:
# True     0.75
# False    0.25
# Name: Funny, dtype: float64

# %%
dataset_edited_car_two['Shows Product Quickly'].value_counts(normalize=True)
# Out:
# True     0.625
# False    0.375
# Name: Shows Product Quickly, dtype: float64

# %%
dataset_edited_car_two['Patriotic'].value_counts(normalize=True)
# Out:
# False    0.8125
# True     0.1875
# Name: Patriotic, dtype: float64

# %%
dataset_edited_car_two['Celebrity'].value_counts(normalize=True)
# Out:
# False    0.6875
# True     0.3125
# Name: Celebrity, dtype: float64

# %%
dataset_edited_car_two['Danger'].value_counts(normalize=True)
# Out:
# True     0.5
# False    0.5
# Name: Danger, dtype: float64

# %%
dataset_edited_car_two['Animals'].value_counts(normalize=True)
# Out:
# False    0.6875
# True     0.3125
# Name: Animals, dtype: float64

# %%
dataset_edited_car_two['Uses Sex'].value_counts(normalize=True)
# Out:
# False    0.75
# True     0.25
# Name: Uses Sex, dtype: float64

# %%
dataset_edited_car_two.plot(x='Year', y='Length')
# Out:
# <AxesSubplot:xlabel='Year'>
